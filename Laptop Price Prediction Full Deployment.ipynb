# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load Train Data

# %%
dfTrain = pd.read_csv("laptops_train.csv")

# %% [markdown]
# ### Explore Train Data

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price
# 0                      NaN  1.37kg  11912523.48
# 1                      NaN  1.34kg   7993374.48
# 2                      NaN  1.86kg   5112900.00
# 3                      NaN  1.83kg  22563005.40
# 4                      NaN  1.37kg  16037611.20

# %%
dfTrain.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price'],
#       dtype='object')

# %%
dfTrain.info() # only operating system version column have null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              977 non-null    object
#  1   Model Name                977 non-null    object
#  2   Category                  977 non-null    object
#  3   Screen Size               977 non-null    object
#  4   Screen                    977 non-null    object
#  5   CPU                       977 non-null    object
#  6   RAM                       977 non-null    object
#  7    Storage                  977 non-null    object
#  8   GPU                       977 non-null    object
#  9   Operating System          977 non-null    object
#  10  Operating System Version  841 non-null    object
#  11  Weight                    977 non-null    object
#  12  Price                     977 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 99.4+ KB

# %%
dfTrain.describe(include = "all")
# Out:
#        Manufacturer Model Name  Category Screen Size             Screen  \
# count           977        977       977         977                977
# unique           19        488         6          18                 38
# top            Dell     XPS 13  Notebook       15.6"  Full HD 1920x1080
# freq            232         22       549         494                397
# mean            NaN        NaN       NaN         NaN                NaN
# std             NaN        NaN       NaN         NaN                NaN
# min             NaN        NaN       NaN         NaN                NaN
# 25%             NaN        NaN       NaN         NaN                NaN
# 50%             NaN        NaN       NaN         NaN                NaN
# 75%             NaN        NaN       NaN         NaN                NaN
# max             NaN        NaN       NaN         NaN                NaN
#
#                                CPU  RAM    Storage                    GPU  \
# count                          977  977        977                    977
# unique                         106    8         36                     98
# top     Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Intel HD Graphics 620
# freq                           151  483        318                    225
# mean                           NaN  NaN        NaN                    NaN
# std                            NaN  NaN        NaN                    NaN
# min                            NaN  NaN        NaN                    NaN
# 25%                            NaN  NaN        NaN                    NaN
# 50%                            NaN  NaN        NaN                    NaN
# 75%                            NaN  NaN        NaN                    NaN
# max                            NaN  NaN        NaN                    NaN
#
#        Operating System Operating System Version Weight         Price
# count               977                      841    977  9.770000e+02
# unique                7                        4    166           NaN
# top             Windows                       10  2.2kg           NaN
# freq                837                      819     98           NaN
# mean                NaN                      NaN    NaN  1.001899e+07
# std                 NaN                      NaN    NaN  6.306430e+06
# min                 NaN                      NaN    NaN  1.706375e+06
# 25%                 NaN                      NaN    NaN  5.326308e+06
# 50%                 NaN                      NaN    NaN  8.527428e+06
# 75%                 NaN                      NaN    NaN  1.311570e+07
# max                 NaN                      NaN    NaN  5.423231e+07

# %%
dfTrain.duplicated().sum() #no duplicates
# Out:
# 0

# %% [markdown]
# ## Training Data preprocessing

# %% [markdown]
# ### removing nan from Operating System Version

# %%
dfTrain.fillna("unknown" , inplace = True)

# %%
dfTrain['Operating System Version']
# Out:
# 0      unknown
# 1      unknown
# 2      unknown
# 3      unknown
# 4      unknown
#         ...
# 972         10
# 973         10
# 974         10
# 975         10
# 976          7
# Name: Operating System Version, Length: 977, dtype: object

# %% [markdown]
# ### Screen Size

# %%
# remove " from size
dfTrain['Screen Size'] = dfTrain['Screen Size'].str.replace('"',"")

# %%
dfTrain['Screen Size']
# Out:
# 0      13.3
# 1      13.3
# 2      15.6
# 3      15.4
# 4      13.3
#        ...
# 972    17.3
# 973    14.0
# 974    17.3
# 975    15.6
# 976    14.0
# Name: Screen Size, Length: 977, dtype: object

# %%
# change data type
dfTrain['Screen Size'] = dfTrain['Screen Size'].astype(float)

# %%
dfTrain['Screen Size']
# Out:
# 0      13.3
# 1      13.3
# 2      15.6
# 3      15.4
# 4      13.3
#        ...
# 972    17.3
# 973    14.0
# 974    17.3
# 975    15.6
# 976    14.0
# Name: Screen Size, Length: 977, dtype: float64

# %% [markdown]
# ### Screen

# %%
dfTrain["Screen"].unique() # there is type , resolution , touch or not
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', 'Touchscreen 2560x1440',
#        '1600x900', 'IPS Panel 4K Ultra HD 3840x2160',
#        '4K Ultra HD 3840x2160', 'Touchscreen 1366x768',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
#        '2560x1440', 'IPS Panel Quad HD+ 2560x1440',
#        'IPS Panel Quad HD+ 3200x1800',
#        'IPS Panel Quad HD+ / Touchscreen 3200x1800',
#        'IPS Panel Touchscreen 1366x768', '1920x1080',
#        'IPS Panel Full HD 1920x1200',
#        'IPS Panel Touchscreen / 4K Ultra HD 3840x2160',
#        'IPS Panel Touchscreen 2560x1440',
#        'Touchscreen / Full HD 1920x1080', 'Quad HD+ 3200x1800'],
#       dtype=object)

# %%
#divide screen column into three columns typeOfScreen ,resolution , touch
#extract resolution 
import re  
def extract_resolution(string):
    pattern = r'\b(\d+x\d+)\b'  # Matches the pattern of digits followed by 'x' and more digits
    match = re.search(pattern, string)
    if match:
        return match.group(1)
    else:
        return None
dfTrain["resolution"] =dfTrain["Screen"].apply(extract_resolution)

# %%
dfTrain["resolution"]
# Out:
# 0      2560x1600
# 1       1440x900
# 2      1920x1080
# 3      2880x1800
# 4      2560x1600
#          ...
# 972    1920x1080
# 973    1920x1080
# 974    1920x1080
# 975    1920x1080
# 976     1366x768
# Name: resolution, Length: 977, dtype: object

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution
# 0                  unknown  1.37kg  11912523.48  2560x1600
# 1                  unknown  1.34kg   7993374.48   1440x900
# 2                  unknown  1.86kg   5112900.00  1920x1080
# 3                  unknown  1.83kg  22563005.40  2880x1800
# 4                  unknown  1.37kg  16037611.20  2560x1600

# %%
#extract touchscreen
dfTrain["touchScren"] =dfTrain["Screen"].str.extract(r'(Touchscreen)')

# %%
dfTrain["touchScren"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 972    NaN
# 973    NaN
# 974    NaN
# 975    NaN
# 976    NaN
# Name: touchScren, Length: 977, dtype: object

# %%
dfTrain["touchScren"] = dfTrain["touchScren"].replace('Touchscreen',1)
dfTrain["touchScren"] = dfTrain["touchScren"].replace(np.nan,0)

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution  touchScren
# 0                  unknown  1.37kg  11912523.48  2560x1600         0.0
# 1                  unknown  1.34kg   7993374.48   1440x900         0.0
# 2                  unknown  1.86kg   5112900.00  1920x1080         0.0
# 3                  unknown  1.83kg  22563005.40  2880x1800         0.0
# 4                  unknown  1.37kg  16037611.20  2560x1600         0.0

# %%
#extract screenType
dfTrain["screenType"] = dfTrain["Screen"]
dfTrain["screenType"] = dfTrain["screenType"].replace(r'(\b\d+x\d+\b)', '' ,regex = True)
dfTrain["screenType"] = dfTrain["screenType"].replace(r'(Touchscreen)', '' , regex = True)
dfTrain["screenType"] = dfTrain["screenType"].replace('Display','', regex = True)
dfTrain["screenType"] = dfTrain["screenType"].replace('',np.nan, regex = True)

# %%
dfTrain.drop("Screen", axis = 1)
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution  touchScren  \
# 0                  unknown  1.37kg  11912523.48  2560x1600         0.0
# 1                  unknown  1.34kg   7993374.48   1440x900         0.0
# 2                  unknown  1.86kg   5112900.00  1920x1080         0.0
# 3                  unknown  1.83kg  22563005.40  2880x1800         0.0
# 4                  unknown  1.37kg  16037611.20  2560x1600         0.0
#
#            screenType
# 0  IPS Panel Retina
# 1                 NaN
# 2            Full HD
# 3  IPS Panel Retina
# 4  IPS Panel Retina

# %% [markdown]
# ### CPU

# %%
dfTrain['CPU'].unique()
#it seems that there is type of CPU and frequency so i will divide this column into two cpuModel and frequency
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
#        'Intel Atom x5-Z8550 1.44GHz',
#        'Intel Celeron Dual Core N3060 1.6GHz', 'Intel Core i5 1.3GHz',
#        'AMD FX 9830P 3GHz', 'Intel Core i7 7560U 2.4GHz',
#        'AMD E-Series 6110 1.5GHz', 'Intel Core i5 6200U 2.3GHz',
#        'Intel Core M 6Y75 1.2GHz', 'Intel Core i5 7500U 2.7GHz',
#        'Intel Core i3 6006U 2.2GHz', 'AMD A6-Series 9220 2.9GHz',
#        'Intel Core i7 6920HQ 2.9GHz', 'Intel Core i5 7Y54 1.2GHz',
#        'Intel Core i7 7820HK 2.9GHz', 'Intel Xeon E3-1505M V6 3GHz',
#        'Intel Core i7 6500U 2.5GHz', 'AMD E-Series 9000e 1.5GHz',
#        'AMD A10-Series A10-9620P 2.5GHz', 'AMD A6-Series A6-9220 2.5GHz',
#        'Intel Core i5 2.9GHz', 'Intel Core i7 6600U 2.6GHz',
#        'Intel Core i3 6006U 2.0GHz',
#        'Intel Celeron Dual Core 3205U 1.5GHz',
#        'Intel Core i7 7820HQ 2.9GHz', 'AMD A10-Series 9600P 2.4GHz',
#        'Intel Core i7 7600U 2.8GHz', 'AMD A8-Series 7410 2.2GHz',
#        'Intel Celeron Dual Core 3855U 1.6GHz',
#        'Intel Pentium Quad Core N3710 1.6GHz',
#        'AMD A12-Series 9720P 2.7GHz', 'Intel Core i5 7300U 2.6GHz',
#        'AMD A12-Series 9720P 3.6GHz',
#        'Intel Celeron Quad Core N3450 1.1GHz',
#        'Intel Celeron Dual Core N3060 1.60GHz',
#        'Intel Core i5 6440HQ 2.6GHz', 'Intel Core i7 6820HQ 2.7GHz',
#        'AMD Ryzen 1600 3.2GHz', 'Intel Core i7 7Y75 1.3GHz',
#        'Intel Core i5 7440HQ 2.8GHz', 'Intel Core i7 7660U 2.5GHz',
#        'Intel Core i7 7700HQ 2.7GHz', 'Intel Core M m3-7Y30 2.2GHz',
#        'Intel Core i5 7Y57 1.2GHz', 'Intel Core i7 6700HQ 2.6GHz',
#        'Intel Core i3 6100U 2.3GHz', 'AMD A10-Series 9620P 2.5GHz',
#        'AMD E-Series 7110 1.8GHz', 'Intel Celeron Dual Core N3350 2.0GHz',
#        'AMD A9-Series A9-9420 3GHz', 'Intel Core i7 6820HK 2.7GHz',
#        'Intel Core M 7Y30 1.0GHz', 'Intel Xeon E3-1535M v6 3.1GHz',
#        'Intel Celeron Quad Core N3160 1.6GHz',
#        'Intel Core i5 6300U 2.4GHz', 'Intel Core i3 6100U 2.1GHz',
#        'AMD E-Series E2-9000 2.2GHz',
#        'Intel Celeron Dual Core N3050 1.6GHz',
#        'Intel Core M M3-6Y30 0.9GHz', 'AMD A9-Series 9420 2.9GHz',
#        'Intel Core i5 6300HQ 2.3GHz', 'AMD A6-Series 7310 2GHz',
#        'Intel Atom Z8350 1.92GHz', 'Intel Xeon E3-1535M v5 2.9GHz',
#        'Intel Core i5 6260U 1.8GHz',
#        'Intel Pentium Dual Core N4200 1.1GHz',
#        'Intel Celeron Quad Core N3710 1.6GHz', 'Intel Core M 1.2GHz',
#        'AMD A12-Series 9700P 2.5GHz', 'Intel Core i7 7500U 2.5GHz',
#        'Intel Pentium Dual Core 4405U 2.1GHz',
#        'AMD A4-Series 7210 2.2GHz', 'Intel Core i7 6560U 2.2GHz',
#        'Intel Core M m7-6Y75 1.2GHz', 'AMD FX 8800P 2.1GHz',
#        'Intel Core M M7-6Y75 1.2GHz', 'Intel Core i5 7200U 2.50GHz',
#        'Intel Core i5 7200U 2.70GHz'], dtype=object)

# %%
#extract frequency
dfTrain["cpuFrequency"] = dfTrain["CPU"].str.extract(r'(\d+\.+\d)')

# %%
dfTrain["cpuFrequency"]
# Out:
# 0      2.3
# 1      1.8
# 2      2.5
# 3      2.7
# 4      3.1
#       ...
# 972    2.6
# 973    2.3
# 974    2.8
# 975    2.7
# 976    2.3
# Name: cpuFrequency, Length: 977, dtype: object

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution  touchScren  \
# 0                  unknown  1.37kg  11912523.48  2560x1600         0.0
# 1                  unknown  1.34kg   7993374.48   1440x900         0.0
# 2                  unknown  1.86kg   5112900.00  1920x1080         0.0
# 3                  unknown  1.83kg  22563005.40  2880x1800         0.0
# 4                  unknown  1.37kg  16037611.20  2560x1600         0.0
#
#            screenType cpuFrequency
# 0  IPS Panel Retina            2.3
# 1                 NaN          1.8
# 2            Full HD           2.5
# 3  IPS Panel Retina            2.7
# 4  IPS Panel Retina            3.1

# %%
#extract Model
dfTrain["cpuModel"] = dfTrain["CPU"]
dfTrain["cpuModel"] = dfTrain["cpuModel"].replace(r'(\d+\.+\d)' , '' , regex = True)
dfTrain["cpuModel"] = dfTrain["cpuModel"].replace(r'(GHz)' , '' , regex = True)

# %%
dfTrain["cpuModel"]
# Out:
# 0             Intel Core i5
# 1             Intel Core i5
# 2       Intel Core i5 7200U
# 3             Intel Core i7
# 4             Intel Core i5
#                ...
# 972    Intel Core i7 6700HQ
# 973     Intel Core i5 6200U
# 974    Intel Core i7 7700HQ
# 975    Intel Core i5 7200U 0
# 976     Intel Core i5 6200U
# Name: cpuModel, Length: 977, dtype: object

# %%
dfTrain["cpuFrequency"] = dfTrain["cpuFrequency"].astype(float)

# %%
dfTrain["cpuFrequency"]
# Out:
# 0      2.3
# 1      1.8
# 2      2.5
# 3      2.7
# 4      3.1
#       ...
# 972    2.6
# 973    2.3
# 974    2.8
# 975    2.7
# 976    2.3
# Name: cpuFrequency, Length: 977, dtype: float64

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution  touchScren  \
# 0                  unknown  1.37kg  11912523.48  2560x1600         0.0
# 1                  unknown  1.34kg   7993374.48   1440x900         0.0
# 2                  unknown  1.86kg   5112900.00  1920x1080         0.0
# 3                  unknown  1.83kg  22563005.40  2880x1800         0.0
# 4                  unknown  1.37kg  16037611.20  2560x1600         0.0
#
#            screenType  cpuFrequency              cpuModel
# 0  IPS Panel Retina             2.3        Intel Core i5
# 1                 NaN           1.8        Intel Core i5
# 2            Full HD            2.5  Intel Core i5 7200U
# 3  IPS Panel Retina             2.7        Intel Core i7
# 4  IPS Panel Retina             3.1        Intel Core i5

# %% [markdown]
# ### RAM

# %%
#remove GB
dfTrain['RAM'] = dfTrain['RAM'].replace(r'(GB)' , '' , regex = True)
dfTrain['RAM'] = dfTrain['RAM'].astype(float)
dfTrain['RAM']
# Out:
# 0       8.0
# 1       8.0
# 2       8.0
# 3      16.0
# 4       8.0
#        ...
# 972    32.0
# 973     8.0
# 974    16.0
# 975     8.0
# 976     4.0
# Name: RAM, Length: 977, dtype: float64

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8.0
# 1                            1440x900        Intel Core i5 1.8GHz   8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8.0
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16.0
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8.0
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution  touchScren  \
# 0                  unknown  1.37kg  11912523.48  2560x1600         0.0
# 1                  unknown  1.34kg   7993374.48   1440x900         0.0
# 2                  unknown  1.86kg   5112900.00  1920x1080         0.0
# 3                  unknown  1.83kg  22563005.40  2880x1800         0.0
# 4                  unknown  1.37kg  16037611.20  2560x1600         0.0
#
#            screenType  cpuFrequency              cpuModel
# 0  IPS Panel Retina             2.3        Intel Core i5
# 1                 NaN           1.8        Intel Core i5
# 2            Full HD            2.5  Intel Core i5 7200U
# 3  IPS Panel Retina             2.7        Intel Core i7
# 4  IPS Panel Retina             3.1        Intel Core i5

# %% [markdown]
# ### Storage

# %%
dfTrain[' Storage'].unique()
# there is a TB and GB as unit so convert TB to GB to have one unit
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '1GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid'], dtype=object)

# %%
dfTrain[' Storage'] = dfTrain[' Storage'].replace(r'(TB)' , '000GB' , regex = True)
dfTrain[' Storage']
# Out:
# 0                    128GB SSD
# 1          128GB Flash Storage
# 2                    256GB SSD
# 3                    512GB SSD
# 4                    256GB SSD
#                 ...
# 972    256GB SSD +  1000GB HDD
# 973                  256GB SSD
# 974    256GB SSD +  1000GB HDD
# 975    128GB SSD +  1000GB HDD
# 976               508GB Hybrid
# Name:  Storage, Length: 977, dtype: object

# %%
#notice that some of devices have two storage so it needs to be split 
dfTrain['secondStorage'] = dfTrain[' Storage'].str.split("+" , n = 1).str[1].str.strip()

# %%
dfTrain['secondStorage']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 972    1000GB HDD
# 973           NaN
# 974    1000GB HDD
# 975    1000GB HDD
# 976           NaN
# Name: secondStorage, Length: 977, dtype: object

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8.0
# 1                            1440x900        Intel Core i5 1.8GHz   8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8.0
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16.0
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8.0
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price resolution  touchScren  \
# 0                  unknown  1.37kg  11912523.48  2560x1600         0.0
# 1                  unknown  1.34kg   7993374.48   1440x900         0.0
# 2                  unknown  1.86kg   5112900.00  1920x1080         0.0
# 3                  unknown  1.83kg  22563005.40  2880x1800         0.0
# 4                  unknown  1.37kg  16037611.20  2560x1600         0.0
#
#            screenType  cpuFrequency              cpuModel secondStorage
# 0  IPS Panel Retina             2.3        Intel Core i5            NaN
# 1                 NaN           1.8        Intel Core i5            NaN
# 2            Full HD            2.5  Intel Core i5 7200U            NaN
# 3  IPS Panel Retina             2.7        Intel Core i7            NaN
# 4  IPS Panel Retina             3.1        Intel Core i5            NaN

# %%
#second storage size
dfTrain['secondStorageSize'] = dfTrain['secondStorage'].str.extract(r'(\d+)')
dfTrain['secondStorage'] =  dfTrain['secondStorage'].replace(r'(\d+)' , '' , regex = True)
dfTrain['secondStorage'] =  dfTrain['secondStorage'].replace(r'(GB)' , '' , regex = True)

# %%
dfTrain['secondStorageSize']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 972    1000
# 973     NaN
# 974    1000
# 975    1000
# 976     NaN
# Name: secondStorageSize, Length: 977, dtype: object

# %%
dfTrain['secondStorage']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 972     HDD
# 973     NaN
# 974     HDD
# 975     HDD
# 976     NaN
# Name: secondStorage, Length: 977, dtype: object

# %%
dfTrain['primaryStorage'] = dfTrain[' Storage'].str.split("+" , n = 1).str[0].str.strip()
dfTrain['primaryStorage'] = dfTrain['primaryStorage'].replace(r'(\d+)','' ,regex = True)
dfTrain['primaryStorage'] = dfTrain['primaryStorage'].replace(r'(GB)','' ,regex = True)

# %%
dfTrain['primaryStorage']
# Out:
# 0                 SSD
# 1       Flash Storage
# 2                 SSD
# 3                 SSD
# 4                 SSD
#             ...
# 972               SSD
# 973               SSD
# 974               SSD
# 975               SSD
# 976            Hybrid
# Name: primaryStorage, Length: 977, dtype: object

# %%
dfTrain['primaryStorageSize'] = dfTrain[' Storage'].str.split("+" , n = 1).str[0].str.strip()
dfTrain['primaryStorageSize'] = dfTrain['primaryStorageSize'].str.extract(r'(\d+)')
dfTrain['primaryStorageSize']
# Out:
# 0      128
# 1      128
# 2      256
# 3      512
# 4      256
#       ...
# 972    256
# 973    256
# 974    256
# 975    128
# 976    508
# Name: primaryStorageSize, Length: 977, dtype: object

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8.0
# 1                            1440x900        Intel Core i5 1.8GHz   8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8.0
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16.0
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8.0
#
#                Storage                           GPU Operating System  ...  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS  ...
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS  ...
# 2            256GB SSD         Intel HD Graphics 620            No OS  ...
# 3            512GB SSD            AMD Radeon Pro 455            macOS  ...
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS  ...
#
#          Price resolution  touchScren          screenType  cpuFrequency  \
# 0  11912523.48  2560x1600         0.0  IPS Panel Retina             2.3
# 1   7993374.48   1440x900         0.0                 NaN           1.8
# 2   5112900.00  1920x1080         0.0            Full HD            2.5
# 3  22563005.40  2880x1800         0.0  IPS Panel Retina             2.7
# 4  16037611.20  2560x1600         0.0  IPS Panel Retina             3.1
#
#                cpuModel  secondStorage secondStorageSize  primaryStorage  \
# 0        Intel Core i5             NaN               NaN             SSD
# 1        Intel Core i5             NaN               NaN   Flash Storage
# 2  Intel Core i5 7200U             NaN               NaN             SSD
# 3        Intel Core i7             NaN               NaN             SSD
# 4        Intel Core i5             NaN               NaN             SSD
#
#   primaryStorageSize
# 0                128
# 1                128
# 2                256
# 3                512
# 4                256
#
# [5 rows x 22 columns]

# %%
dfTrain = dfTrain.drop(' Storage', axis = 1)

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8.0
# 1                            1440x900        Intel Core i5 1.8GHz   8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8.0
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16.0
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8.0
#
#                             GPU Operating System Operating System Version  \
# 0  Intel Iris Plus Graphics 640            macOS                  unknown
# 1        Intel HD Graphics 6000            macOS                  unknown
# 2         Intel HD Graphics 620            No OS                  unknown
# 3            AMD Radeon Pro 455            macOS                  unknown
# 4  Intel Iris Plus Graphics 650            macOS                  unknown
#
#    ...        Price  resolution touchScren          screenType cpuFrequency  \
# 0  ...  11912523.48   2560x1600        0.0  IPS Panel Retina            2.3
# 1  ...   7993374.48    1440x900        0.0                 NaN          1.8
# 2  ...   5112900.00   1920x1080        0.0            Full HD           2.5
# 3  ...  22563005.40   2880x1800        0.0  IPS Panel Retina            2.7
# 4  ...  16037611.20   2560x1600        0.0  IPS Panel Retina            3.1
#
#                cpuModel secondStorage secondStorageSize  primaryStorage  \
# 0        Intel Core i5            NaN               NaN             SSD
# 1        Intel Core i5            NaN               NaN   Flash Storage
# 2  Intel Core i5 7200U            NaN               NaN             SSD
# 3        Intel Core i7            NaN               NaN             SSD
# 4        Intel Core i5            NaN               NaN             SSD
#
#   primaryStorageSize
# 0                128
# 1                128
# 2                256
# 3                512
# 4                256
#
# [5 rows x 21 columns]

# %% [markdown]
# ### GPU

# %%
dfTrain['GPU'].unique()
#no need for preprocessing
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Intel HD Graphics 400',
#        'Nvidia GeForce GTX 1050', 'AMD Radeon R2', 'AMD Radeon 530',
#        'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Nvidia GeForce MX130', 'AMD R4 Graphics',
#        'Nvidia GeForce GTX 940MX', 'AMD Radeon RX 560',
#        'Nvidia GeForce 920M', 'AMD Radeon R7 M445', 'AMD Radeon RX 550',
#        'Nvidia GeForce GTX 1050M', 'Intel HD Graphics 515',
#        'AMD Radeon R5 M420', 'Intel HD Graphics 505',
#        'Nvidia GTX 980 SLI', 'AMD R17M-M1-70', 'Nvidia GeForce GTX 1080',
#        'Nvidia Quadro M1200', 'Nvidia GeForce 920MX ',
#        'Nvidia GeForce GTX 950M', 'AMD FirePro W4190M ',
#        'Nvidia GeForce GTX 980M', 'Intel Iris Graphics 550',
#        'Nvidia GeForce 930M', 'Intel HD Graphics 630',
#        'AMD Radeon R5 430', 'Nvidia GeForce GTX 940M',
#        'Intel HD Graphics 510', 'Intel HD Graphics 405',
#        'AMD Radeon RX 540', 'Nvidia GeForce GT 940MX',
#        'AMD FirePro W5130M', 'Nvidia Quadro M2200M', 'AMD Radeon R4',
#        'Nvidia Quadro M620', 'AMD Radeon R7 M460',
#        'Intel HD Graphics 530', 'Nvidia GeForce GTX 965M',
#        'Nvidia GeForce GTX1080', 'Nvidia GeForce GTX1050 Ti',
#        'Nvidia GeForce GTX 960M', 'AMD Radeon R2 Graphics',
#        'Nvidia Quadro M620M', 'Nvidia GeForce GTX 970M',
#        'Nvidia GeForce GTX 960<U+039C>', 'Intel Graphics 620',
#        'Nvidia GeForce GTX 960', 'AMD Radeon R5 520',
#        'AMD Radeon R7 M440', 'AMD Radeon R7', 'Nvidia Quadro M520M',
#        'Nvidia Quadro M2200', 'Nvidia Quadro M2000M',
#        'Intel HD Graphics 540', 'Nvidia Quadro M1000M', 'AMD Radeon 540',
#        'Nvidia GeForce GTX 1070M', 'Nvidia GeForce GTX1060',
#        'Intel HD Graphics 5300', 'AMD Radeon R5 M420X',
#        'AMD Radeon R7 Graphics', 'Nvidia GeForce 920',
#        'Nvidia GeForce 940M', 'Nvidia GeForce GTX 930MX',
#        'AMD Radeon R7 M465', 'AMD Radeon R3', 'Nvidia GeForce GTX 1050Ti',
#        'AMD Radeon R7 M365X', 'AMD Radeon R9 M385'], dtype=object)

# %% [markdown]
# ### Weight

# %%
# remove kg and change dtype
dfTrain['Weight'].unique()
# Out:
# array(['1.37kg', '1.34kg', '1.86kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg',
#        '1.6kg', '2.2kg', '0.92kg', '1.22kg', '0.98kg', '2.5kg', '1.62kg',
#        '1.91kg', '2.3kg', '1.35kg', '1.88kg', '1.89kg', '1.65kg',
#        '2.71kg', '1.2kg', '1.44kg', '2.8kg', '2kg', '2.65kg', '2.77kg',
#        '3.2kg', '0.69kg', '1.49kg', '2.4kg', '2.13kg', '2.43kg', '1.7kg',
#        '1.4kg', '1.8kg', '1.9kg', '3kg', '1.252kg', '2.7kg', '2.02kg',
#        '1.63kg', '1.96kg', '1.21kg', '2.45kg', '1.25kg', '1.5kg',
#        '2.62kg', '1.38kg', '1.58kg', '1.85kg', '1.23kg', '1.26kg',
#        '2.16kg', '2.36kg', '2.05kg', '1.32kg', '1.75kg', '0.97kg',
#        '2.9kg', '2.56kg', '1.48kg', '1.74kg', '1.1kg', '1.56kg', '2.03kg',
#        '1.05kg', '4.4kg', '1.90kg', '1.29kg', '2.0kg', '1.95kg', '2.06kg',
#        '1.12kg', '1.42kg', '3.49kg', '3.35kg', '2.23kg', '4.42kg',
#        '2.69kg', '2.37kg', '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg',
#        '1.41kg', '4.14kg', '2.18kg', '2.24kg', '2.67kg', '2.14kg',
#        '1.36kg', '2.25kg', '2.15kg', '2.19kg', '2.54kg', '3.42kg',
#        '1.28kg', '2.33kg', '1.45kg', '2.79kg', '1.84kg', '2.6kg',
#        '2.26kg', '3.25kg', '1.59kg', '1.13kg', '1.78kg', '1.10kg',
#        '1.15kg', '1.27kg', '1.43kg', '2.31kg', '1.16kg', '1.64kg',
#        '2.17kg', '1.47kg', '3.78kg', '1.79kg', '0.91kg', '1.99kg',
#        '4.33kg', '1.93kg', '1.87kg', '2.63kg', '3.4kg', '3.14kg',
#        '1.94kg', '1.24kg', '4.6kg', '4.5kg', '2.73kg', '1.39kg', '2.29kg',
#        '2.59kg', '2.94kg', '1.14kg', '3.8kg', '3.31kg', '1.09kg',
#        '3.21kg', '1.19kg', '1.98kg', '1.17kg', '4.36kg', '1.71kg',
#        '2.32kg', '4.2kg', '1.55kg', '0.81kg', '1.18kg', '2.72kg',
#        '1.31kg', '0.920kg', '3.74kg', '1.76kg', '1.54kg', '2.83kg',
#        '2.07kg', '2.38kg', '3.58kg', '1.08kg', '2.20kg', '2.75kg',
#        '1.70kg'], dtype=object)

# %%
dfTrain['Weight'] = dfTrain['Weight'].str.replace('kg','')
dfTrain['Weight'] = dfTrain['Weight'].astype(float)
dfTrain['Weight']
# Out:
# 0      1.37
# 1      1.34
# 2      1.86
# 3      1.83
# 4      1.37
#        ...
# 972    4.42
# 973    1.95
# 974    2.73
# 975    2.04
# 976    1.70
# Name: Weight, Length: 977, dtype: float64

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8.0
# 1                            1440x900        Intel Core i5 1.8GHz   8.0
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8.0
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16.0
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8.0
#
#                             GPU Operating System Operating System Version  \
# 0  Intel Iris Plus Graphics 640            macOS                  unknown
# 1        Intel HD Graphics 6000            macOS                  unknown
# 2         Intel HD Graphics 620            No OS                  unknown
# 3            AMD Radeon Pro 455            macOS                  unknown
# 4  Intel Iris Plus Graphics 650            macOS                  unknown
#
#    ...        Price  resolution touchScren          screenType cpuFrequency  \
# 0  ...  11912523.48   2560x1600        0.0  IPS Panel Retina            2.3
# 1  ...   7993374.48    1440x900        0.0                 NaN          1.8
# 2  ...   5112900.00   1920x1080        0.0            Full HD           2.5
# 3  ...  22563005.40   2880x1800        0.0  IPS Panel Retina            2.7
# 4  ...  16037611.20   2560x1600        0.0  IPS Panel Retina            3.1
#
#                cpuModel secondStorage secondStorageSize  primaryStorage  \
# 0        Intel Core i5            NaN               NaN             SSD
# 1        Intel Core i5            NaN               NaN   Flash Storage
# 2  Intel Core i5 7200U            NaN               NaN             SSD
# 3        Intel Core i7            NaN               NaN             SSD
# 4        Intel Core i5            NaN               NaN             SSD
#
#   primaryStorageSize
# 0                128
# 1                128
# 2                256
# 3                512
# 4                256
#
# [5 rows x 21 columns]

# %%
dfTrain = dfTrain.drop(['Screen', 'CPU'] , axis = 1)

# %%
dfTrain.head()
# Out:
#   Manufacturer   Model Name   Category  Screen Size   RAM  \
# 0        Apple  MacBook Pro  Ultrabook         13.3   8.0
# 1        Apple  Macbook Air  Ultrabook         13.3   8.0
# 2           HP       250 G6   Notebook         15.6   8.0
# 3        Apple  MacBook Pro  Ultrabook         15.4  16.0
# 4        Apple  MacBook Pro  Ultrabook         13.3   8.0
#
#                             GPU Operating System Operating System Version  \
# 0  Intel Iris Plus Graphics 640            macOS                  unknown
# 1        Intel HD Graphics 6000            macOS                  unknown
# 2         Intel HD Graphics 620            No OS                  unknown
# 3            AMD Radeon Pro 455            macOS                  unknown
# 4  Intel Iris Plus Graphics 650            macOS                  unknown
#
#    Weight        Price resolution  touchScren          screenType  \
# 0    1.37  11912523.48  2560x1600         0.0  IPS Panel Retina
# 1    1.34   7993374.48   1440x900         0.0                 NaN
# 2    1.86   5112900.00  1920x1080         0.0            Full HD
# 3    1.83  22563005.40  2880x1800         0.0  IPS Panel Retina
# 4    1.37  16037611.20  2560x1600         0.0  IPS Panel Retina
#
#    cpuFrequency              cpuModel secondStorage secondStorageSize  \
# 0           2.3        Intel Core i5            NaN               NaN
# 1           1.8        Intel Core i5            NaN               NaN
# 2           2.5  Intel Core i5 7200U            NaN               NaN
# 3           2.7        Intel Core i7            NaN               NaN
# 4           3.1        Intel Core i5            NaN               NaN
#
#    primaryStorage primaryStorageSize
# 0             SSD                128
# 1   Flash Storage                128
# 2             SSD                256
# 3             SSD                512
# 4             SSD                256

# %% [markdown]
# ## Test Data preprocessing

# %%
dfTest = pd.read_csv('laptops_test.csv')

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#   Screen Size                                     Screen  \
# 0       15.6"                                   1366x768
# 1       17.3"                          Full HD 1920x1080
# 2       15.6"  IPS Panel Full HD / Touchscreen 1920x1080
# 3       13.3"                          Full HD 1920x1080
# 4       15.6"                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz  12GB             512GB SSD
# 3   Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 4  AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
#
#                           GPU Operating System Operating System Version  \
# 0       Intel HD Graphics 620          Windows                       10
# 1  Nvidia GeForce GTX 1050 Ti          Windows                       10
# 2       Intel HD Graphics 620          Windows                       10
# 3       Intel HD Graphics 520          Windows                        7
# 4              AMD Radeon 530          Windows                       10
#
#    Weight       Price
# 0  2.04kg   5148468.0
# 1  2.99kg  15552108.0
# 2  2.19kg  11550708.0
# 3   1.2kg  10625940.0
# 4   2.2kg   4881708.0

# %%
dfTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              325 non-null    object
#  1   Model Name                325 non-null    object
#  2   Category                  325 non-null    object
#  3   Screen Size               325 non-null    object
#  4   Screen                    325 non-null    object
#  5   CPU                       325 non-null    object
#  6   RAM                       325 non-null    object
#  7    Storage                  325 non-null    object
#  8   GPU                       325 non-null    object
#  9   Operating System          325 non-null    object
#  10  Operating System Version  291 non-null    object
#  11  Weight                    325 non-null    object
#  12  Price                     325 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 33.1+ KB

# %%
dfTest.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price'],
#       dtype='object')

# %%
dfTest.fillna("unknown", inplace= True)

# %%
dfTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              325 non-null    object
#  1   Model Name                325 non-null    object
#  2   Category                  325 non-null    object
#  3   Screen Size               325 non-null    object
#  4   Screen                    325 non-null    object
#  5   CPU                       325 non-null    object
#  6   RAM                       325 non-null    object
#  7    Storage                  325 non-null    object
#  8   GPU                       325 non-null    object
#  9   Operating System          325 non-null    object
#  10  Operating System Version  325 non-null    object
#  11  Weight                    325 non-null    object
#  12  Price                     325 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 33.1+ KB

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#   Screen Size                                     Screen  \
# 0       15.6"                                   1366x768
# 1       17.3"                          Full HD 1920x1080
# 2       15.6"  IPS Panel Full HD / Touchscreen 1920x1080
# 3       13.3"                          Full HD 1920x1080
# 4       15.6"                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz  12GB             512GB SSD
# 3   Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 4  AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
#
#                           GPU Operating System Operating System Version  \
# 0       Intel HD Graphics 620          Windows                       10
# 1  Nvidia GeForce GTX 1050 Ti          Windows                       10
# 2       Intel HD Graphics 620          Windows                       10
# 3       Intel HD Graphics 520          Windows                        7
# 4              AMD Radeon 530          Windows                       10
#
#    Weight       Price
# 0  2.04kg   5148468.0
# 1  2.99kg  15552108.0
# 2  2.19kg  11550708.0
# 3   1.2kg  10625940.0
# 4   2.2kg   4881708.0

# %%
dfTest['Screen Size'] = dfTest['Screen Size'].str.replace('"' , '')
dfTest['Screen Size'] = dfTest['Screen Size'].astype(float)

# %%
dfTest['Screen Size']
# Out:
# 0      15.6
# 1      17.3
# 2      15.6
# 3      13.3
# 4      15.6
#        ...
# 320    14.0
# 321    13.3
# 322    14.0
# 323    15.6
# 324    15.6
# Name: Screen Size, Length: 325, dtype: float64

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size                                     Screen  \
# 0         15.6                                   1366x768
# 1         17.3                          Full HD 1920x1080
# 2         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 3         13.3                          Full HD 1920x1080
# 4         15.6                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz  12GB             512GB SSD
# 3   Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 4  AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
#
#                           GPU Operating System Operating System Version  \
# 0       Intel HD Graphics 620          Windows                       10
# 1  Nvidia GeForce GTX 1050 Ti          Windows                       10
# 2       Intel HD Graphics 620          Windows                       10
# 3       Intel HD Graphics 520          Windows                        7
# 4              AMD Radeon 530          Windows                       10
#
#    Weight       Price
# 0  2.04kg   5148468.0
# 1  2.99kg  15552108.0
# 2  2.19kg  11550708.0
# 3   1.2kg  10625940.0
# 4   2.2kg   4881708.0

# %%
import re  
def extract_resolution(string):
    pattern = r'\b(\d+x\d+)\b'  # Matches the pattern of digits followed by 'x' and more digits
    match = re.search(pattern, string)
    if match:
        return match.group(1)
    else:
        return None
dfTest["resolution"] =dfTest["Screen"].apply(extract_resolution)

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size                                     Screen  \
# 0         15.6                                   1366x768
# 1         17.3                          Full HD 1920x1080
# 2         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 3         13.3                          Full HD 1920x1080
# 4         15.6                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz  12GB             512GB SSD
# 3   Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 4  AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
#
#                           GPU Operating System Operating System Version  \
# 0       Intel HD Graphics 620          Windows                       10
# 1  Nvidia GeForce GTX 1050 Ti          Windows                       10
# 2       Intel HD Graphics 620          Windows                       10
# 3       Intel HD Graphics 520          Windows                        7
# 4              AMD Radeon 530          Windows                       10
#
#    Weight       Price resolution
# 0  2.04kg   5148468.0   1366x768
# 1  2.99kg  15552108.0  1920x1080
# 2  2.19kg  11550708.0  1920x1080
# 3   1.2kg  10625940.0  1920x1080
# 4   2.2kg   4881708.0  1920x1080

# %%
dfTest["touchScren"] =dfTest["Screen"].str.extract(r'(Touchscreen)')
dfTest["touchScren"] = dfTest["touchScren"].replace('Touchscreen',1)
dfTest["touchScren"] = dfTest["touchScren"].replace(np.nan,0)

# %%
dfTest["touchScren"]
# Out:
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      0.0
#       ...
# 320    1.0
# 321    1.0
# 322    0.0
# 323    0.0
# 324    0.0
# Name: touchScren, Length: 325, dtype: float64

# %%
dfTest["screenType"] = dfTest["Screen"]
dfTest["screenType"] = dfTest["screenType"].replace(r'(\b\d+x\d+\b)', '' ,regex = True)
dfTest["screenType"] = dfTest["screenType"].replace(r'(Touchscreen)', '' , regex = True)
dfTest["screenType"] = dfTest["screenType"].replace('Display','', regex = True)
dfTest["screenType"] = dfTest["screenType"].replace('',np.nan, regex = True)

# %%
dfTest["screenType"]
# Out:
# 0                         NaN
# 1                    Full HD
# 2       IPS Panel Full HD /
# 3                    Full HD
# 4                    Full HD
#                 ...
# 320     IPS Panel Full HD /
# 321    IPS Panel Quad HD+ /
# 322                       NaN
# 323                       NaN
# 324                       NaN
# Name: screenType, Length: 325, dtype: object

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size                                     Screen  \
# 0         15.6                                   1366x768
# 1         17.3                          Full HD 1920x1080
# 2         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 3         13.3                          Full HD 1920x1080
# 4         15.6                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 2   Intel Core i7 7500U 2.7GHz  12GB             512GB SSD
# 3   Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 4  AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
#
#                           GPU Operating System Operating System Version  \
# 0       Intel HD Graphics 620          Windows                       10
# 1  Nvidia GeForce GTX 1050 Ti          Windows                       10
# 2       Intel HD Graphics 620          Windows                       10
# 3       Intel HD Graphics 520          Windows                        7
# 4              AMD Radeon 530          Windows                       10
#
#    Weight       Price resolution  touchScren             screenType
# 0  2.04kg   5148468.0   1366x768         0.0                    NaN
# 1  2.99kg  15552108.0  1920x1080         0.0               Full HD
# 2  2.19kg  11550708.0  1920x1080         1.0  IPS Panel Full HD /
# 3   1.2kg  10625940.0  1920x1080         0.0               Full HD
# 4   2.2kg   4881708.0  1920x1080         0.0               Full HD

# %%
dfTest = dfTest.drop('Screen',axis = 1 )

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size                          CPU   RAM               Storage  \
# 0         15.6   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1         17.3  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 2         15.6   Intel Core i7 7500U 2.7GHz  12GB             512GB SSD
# 3         13.3   Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 4         15.6  AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
#
#                           GPU Operating System Operating System Version  \
# 0       Intel HD Graphics 620          Windows                       10
# 1  Nvidia GeForce GTX 1050 Ti          Windows                       10
# 2       Intel HD Graphics 620          Windows                       10
# 3       Intel HD Graphics 520          Windows                        7
# 4              AMD Radeon 530          Windows                       10
#
#    Weight       Price resolution  touchScren             screenType
# 0  2.04kg   5148468.0   1366x768         0.0                    NaN
# 1  2.99kg  15552108.0  1920x1080         0.0               Full HD
# 2  2.19kg  11550708.0  1920x1080         1.0  IPS Panel Full HD /
# 3   1.2kg  10625940.0  1920x1080         0.0               Full HD
# 4   2.2kg   4881708.0  1920x1080         0.0               Full HD

# %%
dfTest["cpuFrequency"] = dfTest["CPU"].str.extract(r'(\d+\.+\d)')
dfTrain["cpuFrequency"] = dfTrain["cpuFrequency"].astype(float)
dfTest["cpuModel"] = dfTest["CPU"]
dfTest["cpuModel"] = dfTest["cpuModel"].replace(r'(\d+\.+\d)' , '' , regex = True)
dfTest["cpuModel"] = dfTest["cpuModel"].replace(r'(GHz)' , '' , regex = True)

# %%
dfTest = dfTest.drop('CPU',axis = 1)

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size   RAM               Storage                         GPU  \
# 0         15.6   6GB               1TB HDD       Intel HD Graphics 620
# 1         17.3  16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti
# 2         15.6  12GB             512GB SSD       Intel HD Graphics 620
# 3         13.3   4GB             128GB SSD       Intel HD Graphics 520
# 4         15.6   6GB             256GB SSD              AMD Radeon 530
#
#   Operating System Operating System Version  Weight       Price resolution  \
# 0          Windows                       10  2.04kg   5148468.0   1366x768
# 1          Windows                       10  2.99kg  15552108.0  1920x1080
# 2          Windows                       10  2.19kg  11550708.0  1920x1080
# 3          Windows                        7   1.2kg  10625940.0  1920x1080
# 4          Windows                       10   2.2kg   4881708.0  1920x1080
#
#    touchScren             screenType cpuFrequency               cpuModel
# 0         0.0                    NaN          2.7   Intel Core i7 7500U
# 1         0.0               Full HD           2.8  Intel Core i7 7700HQ
# 2         1.0  IPS Panel Full HD /            2.7   Intel Core i7 7500U
# 3         0.0               Full HD           2.3   Intel Core i5 6200U
# 4         0.0               Full HD           3.6  AMD A12-Series 9720P

# %%
dfTest['RAM'] = dfTest['RAM'].replace(r'(GB)' , '' , regex = True)
dfTest['RAM'] = dfTest['RAM'].astype(float)
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size   RAM               Storage                         GPU  \
# 0         15.6   6.0               1TB HDD       Intel HD Graphics 620
# 1         17.3  16.0  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti
# 2         15.6  12.0             512GB SSD       Intel HD Graphics 620
# 3         13.3   4.0             128GB SSD       Intel HD Graphics 520
# 4         15.6   6.0             256GB SSD              AMD Radeon 530
#
#   Operating System Operating System Version  Weight       Price resolution  \
# 0          Windows                       10  2.04kg   5148468.0   1366x768
# 1          Windows                       10  2.99kg  15552108.0  1920x1080
# 2          Windows                       10  2.19kg  11550708.0  1920x1080
# 3          Windows                        7   1.2kg  10625940.0  1920x1080
# 4          Windows                       10   2.2kg   4881708.0  1920x1080
#
#    touchScren             screenType cpuFrequency               cpuModel
# 0         0.0                    NaN          2.7   Intel Core i7 7500U
# 1         0.0               Full HD           2.8  Intel Core i7 7700HQ
# 2         1.0  IPS Panel Full HD /            2.7   Intel Core i7 7500U
# 3         0.0               Full HD           2.3   Intel Core i5 6200U
# 4         0.0               Full HD           3.6  AMD A12-Series 9720P

# %%
dfTest[' Storage'] = dfTest[' Storage'].replace(r'(TB)' , '000GB' , regex = True)
dfTest[' Storage']
# Out:
# 0                   1000GB HDD
# 1      256GB SSD +  1000GB HDD
# 2                    512GB SSD
# 3                    128GB SSD
# 4                    256GB SSD
#                 ...
# 320                  128GB SSD
# 321                  512GB SSD
# 322         64GB Flash Storage
# 323                 1000GB HDD
# 324                  500GB HDD
# Name:  Storage, Length: 325, dtype: object

# %%
dfTest['secondStorage'] = dfTest[' Storage'].str.split("+" , n = 1).str[1].str.strip()
dfTest['secondStorageSize'] = dfTest['secondStorage'].str.extract(r'(\d+)')
dfTest['secondStorage'] =  dfTest['secondStorage'].replace(r'(\d+)' , '' , regex = True)
dfTest['secondStorage'] =  dfTest['secondStorage'].replace(r'(GB)' , '' , regex = True)

# %%
dfTest['primaryStorage'] = dfTest[' Storage'].str.split("+" , n = 1).str[0].str.strip()
dfTest['primaryStorage'] = dfTest['primaryStorage'].replace(r'(\d+)','' ,regex = True)
dfTest['primaryStorage'] = dfTest['primaryStorage'].replace(r'(GB)','' ,regex = True)

dfTest['primaryStorageSize'] = dfTest[' Storage'].str.split("+" , n = 1).str[0].str.strip()
dfTest['primaryStorageSize'] = dfTest['primaryStorageSize'].str.extract(r'(\d+)')

# %%
dfTest = dfTest.drop(' Storage', axis = 1)

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size   RAM                         GPU Operating System  \
# 0         15.6   6.0       Intel HD Graphics 620          Windows
# 1         17.3  16.0  Nvidia GeForce GTX 1050 Ti          Windows
# 2         15.6  12.0       Intel HD Graphics 620          Windows
# 3         13.3   4.0       Intel HD Graphics 520          Windows
# 4         15.6   6.0              AMD Radeon 530          Windows
#
#   Operating System Version  Weight       Price resolution  touchScren  \
# 0                       10  2.04kg   5148468.0   1366x768         0.0
# 1                       10  2.99kg  15552108.0  1920x1080         0.0
# 2                       10  2.19kg  11550708.0  1920x1080         1.0
# 3                        7   1.2kg  10625940.0  1920x1080         0.0
# 4                       10   2.2kg   4881708.0  1920x1080         0.0
#
#               screenType cpuFrequency               cpuModel secondStorage  \
# 0                    NaN          2.7   Intel Core i7 7500U            NaN
# 1               Full HD           2.8  Intel Core i7 7700HQ            HDD
# 2  IPS Panel Full HD /            2.7   Intel Core i7 7500U            NaN
# 3               Full HD           2.3   Intel Core i5 6200U            NaN
# 4               Full HD           3.6  AMD A12-Series 9720P            NaN
#
#   secondStorageSize primaryStorage primaryStorageSize
# 0               NaN            HDD               1000
# 1              1000            SSD                256
# 2               NaN            SSD                512
# 3               NaN            SSD                128
# 4               NaN            SSD                256

# %%
dfTest['Weight'] = dfTest['Weight'].str.replace('kg','')
dfTest['Weight'] = dfTest['Weight'].str.replace('s','')
dfTest['Weight']  = dfTest['Weight'].astype(float)

# %%
dfTest.head()
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size   RAM                         GPU Operating System  \
# 0         15.6   6.0       Intel HD Graphics 620          Windows
# 1         17.3  16.0  Nvidia GeForce GTX 1050 Ti          Windows
# 2         15.6  12.0       Intel HD Graphics 620          Windows
# 3         13.3   4.0       Intel HD Graphics 520          Windows
# 4         15.6   6.0              AMD Radeon 530          Windows
#
#   Operating System Version  Weight       Price resolution  touchScren  \
# 0                       10    2.04   5148468.0   1366x768         0.0
# 1                       10    2.99  15552108.0  1920x1080         0.0
# 2                       10    2.19  11550708.0  1920x1080         1.0
# 3                        7    1.20  10625940.0  1920x1080         0.0
# 4                       10    2.20   4881708.0  1920x1080         0.0
#
#               screenType cpuFrequency               cpuModel secondStorage  \
# 0                    NaN          2.7   Intel Core i7 7500U            NaN
# 1               Full HD           2.8  Intel Core i7 7700HQ            HDD
# 2  IPS Panel Full HD /            2.7   Intel Core i7 7500U            NaN
# 3               Full HD           2.3   Intel Core i5 6200U            NaN
# 4               Full HD           3.6  AMD A12-Series 9720P            NaN
#
#   secondStorageSize primaryStorage primaryStorageSize
# 0               NaN            HDD               1000
# 1              1000            SSD                256
# 2               NaN            SSD                512
# 3               NaN            SSD                128
# 4               NaN            SSD                256

# %% [markdown]
# ## Model

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Training

# %%
trainingData = dfTrain

# %%
x = trainingData.drop('Price' , axis = 1)
y = trainingData['Price']

# %%
x.head()
# Out:
#    Manufacturer  Model Name  Category  Screen Size  RAM  GPU  \
# 0             1         236         4            7    3   51
# 1             1         237         4            7    3   45
# 2             7          38         3           14    3   47
# 3             1         236         4           13    5    7
# 4             1         236         4            7    3   52
#
#    Operating System  Operating System Version  Weight  resolution  touchScren  \
# 0                 6                         4      35          10           0
# 1                 6                         4      32           1           0
# 2                 4                         4      70           3           0
# 3                 6                         4      67          12           0
# 4                 6                         4      35          10           0
#
#            screenType  cpuFrequency              cpuModel secondStorage  \
# 0  IPS Panel Retina             2.3        Intel Core i5            NaN
# 1                 NaN           1.8        Intel Core i5            NaN
# 2            Full HD            2.5  Intel Core i5 7200U            NaN
# 3  IPS Panel Retina             2.7        Intel Core i7            NaN
# 4  IPS Panel Retina             3.1        Intel Core i5            NaN
#
#   secondStorageSize  primaryStorage primaryStorageSize
# 0               NaN             SSD                128
# 1               NaN   Flash Storage                128
# 2               NaN             SSD                256
# 3               NaN             SSD                512
# 4               NaN             SSD                256

# %%
x['screenType'] = x['screenType'].astype(str)
x['cpuModel'] = x['cpuModel'].astype(str)
x['secondStorage'] = x['secondStorage'].astype(str)
x['primaryStorage'] = x['primaryStorage'].astype(str)
x['cpuFrequency'] = x['cpuFrequency'].astype(float)
x['secondStorageSize'] = x['secondStorageSize'].astype(float)

encoder = preprocessing.LabelEncoder()
xColumns = x.columns
for col in xColumns:
    x[col] = encoder.fit_transform(x[col])
x
# Out:
#      Manufacturer  Model Name  Category  Screen Size  RAM  GPU  \
# 0               1         236         4            7    3   51
# 1               1         237         4            7    3   45
# 2               7          38         3           14    3   47
# 3               1         236         4           13    5    7
# 4               1         236         4            7    3   52
# ..            ...         ...       ...          ...  ...  ...
# 972             4          43         1           16    7   72
# 973            16         339         3           10    3   41
# 974             2         318         1           16    5   71
# 975             7         293         3           14    3   62
# 976            10         362         3           10    1   41
#
#      Operating System  Operating System Version  Weight  resolution  \
# 0                   6                         4      35          10
# 1                   6                         4      32           1
# 2                   4                         4      70           3
# 3                   6                         4      67          12
# 4                   6                         4      35          10
# ..                ...                       ...     ...         ...
# 972                 5                         0     156           3
# 973                 5                         0      78           3
# 974                 5                         0     127           3
# 975                 5                         0      85           3
# 976                 5                         2      59           0
#
#      touchScren  screenType  cpuFrequency  cpuModel  secondStorage  \
# 0             0          10            13        29              2
# 1             0          13             8        29              2
# 2             0          17            15         4              2
# 3             0          10            17         9              2
# 4             0          10            20        29              2
# ..          ...         ...           ...       ...            ...
# 972           0          17            16        18              0
# 973           0          17            13        85              2
# 974           0          17            18        42              0
# 975           0           6            17        16              0
# 976           0          13            13        85              2
#
#      secondStorageSize  primaryStorage  primaryStorageSize
# 0                    5               3                   2
# 1                    5               0                   2
# 2                    5               3                   6
# 3                    5               3                  10
# 4                    5               3                   6
# ..                 ...             ...                 ...
# 972                  3               3                   6
# 973                  5               3                   6
# 974                  3               3                   6
# 975                  3               3                   2
# 976                  5               2                   9
#
# [977 rows x 18 columns]

# %% [markdown]
# ### Testing

# %%
testingData = dfTest
xTest = testingData.drop('Price' , axis = 1)
yTest = testingData['Price']

# %%
xTest = xTest.rename(columns={'Model Name': 'modelName' ,'Operating System':'operatingSystem','Operating System Version':'operatingSystemVersion' })

xTest
# Out:
#     Manufacturer                            modelName            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 320       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 321       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 322       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 323           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 324         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size   RAM                         GPU operatingSystem  \
# 0           15.6   6.0       Intel HD Graphics 620         Windows
# 1           17.3  16.0  Nvidia GeForce GTX 1050 Ti         Windows
# 2           15.6  12.0       Intel HD Graphics 620         Windows
# 3           13.3   4.0       Intel HD Graphics 520         Windows
# 4           15.6   6.0              AMD Radeon 530         Windows
# ..           ...   ...                         ...             ...
# 320         14.0   4.0       Intel HD Graphics 520         Windows
# 321         13.3  16.0       Intel HD Graphics 520         Windows
# 322         14.0   2.0           Intel HD Graphics         Windows
# 323         15.6   6.0          AMD Radeon R5 M330         Windows
# 324         15.6   4.0           Intel HD Graphics         Windows
#
#     operatingSystemVersion  Weight resolution  touchScren  \
# 0                       10    2.04   1366x768         0.0
# 1                       10    2.99  1920x1080         0.0
# 2                       10    2.19  1920x1080         1.0
# 3                        7    1.20  1920x1080         0.0
# 4                       10    2.20  1920x1080         0.0
# ..                     ...     ...        ...         ...
# 320                     10    1.80  1920x1080         1.0
# 321                     10    1.30  3200x1800         1.0
# 322                     10    1.50   1366x768         0.0
# 323                     10    2.19   1366x768         0.0
# 324                     10    2.20   1366x768         0.0
#
#                  screenType cpuFrequency                        cpuModel  \
# 0                       NaN          2.7            Intel Core i7 7500U
# 1                  Full HD           2.8           Intel Core i7 7700HQ
# 2     IPS Panel Full HD /            2.7            Intel Core i7 7500U
# 3                  Full HD           2.3            Intel Core i5 6200U
# 4                  Full HD           3.6           AMD A12-Series 9720P
# ..                      ...          ...                             ...
# 320   IPS Panel Full HD /            2.5            Intel Core i7 6500U
# 321  IPS Panel Quad HD+ /            2.5            Intel Core i7 6500U
# 322                     NaN          1.6  Intel Celeron Dual Core N3050
# 323                     NaN          2.5            Intel Core i7 6500U
# 324                     NaN          1.6  Intel Celeron Dual Core N3050
#
#     secondStorage secondStorageSize  primaryStorage primaryStorageSize
# 0             NaN               NaN             HDD               1000
# 1             HDD              1000             SSD                256
# 2             NaN               NaN             SSD                512
# 3             NaN               NaN             SSD                128
# 4             NaN               NaN             SSD                256
# ..            ...               ...             ...                ...
# 320           NaN               NaN             SSD                128
# 321           NaN               NaN             SSD                512
# 322           NaN               NaN   Flash Storage                 64
# 323           NaN               NaN             HDD               1000
# 324           NaN               NaN             HDD                500
#
# [325 rows x 18 columns]

# %%
xTest.resolution = encoder.fit_transform(xTest.resolution)

# %%
xTest['screenType'] = xTest['screenType'].astype(str)
xTest['cpuModel'] = xTest['cpuModel'].astype(str)
xTest['secondStorage'] = xTest['secondStorage'].astype(str)
xTest['primaryStorage'] = xTest['primaryStorage'].astype(str)
xTest['cpuFrequency'] = xTest['cpuFrequency'].astype(float)
xTest['secondStorageSize'] = xTest['secondStorageSize'].astype(float)
xTest['modelName'] = xTest['modelName'].astype(str)
encoder = preprocessing.LabelEncoder()
xTestColumns = xTest.columns
for col in xTestColumns:
    xTest[col] = encoder.fit_transform(xTest[col])
xTest
# Out:
#      Manufacturer  modelName  Category  Screen Size  RAM  GPU  \
# 0               5        142         3            8    2   25
# 1               2         44         1            9    5   38
# 2               3        185         0            8    4   25
# 3              10         16         3            5    1   21
# 4               6        165         3            8    2    3
# ..            ...        ...       ...          ...  ...  ...
# 320             6         96         0            6    1   21
# 321             6         98         0            5    5   21
# 322             6        160         3            6    0   15
# 323             5          0         3            8    2    9
# 324             2         91         3            8    1   15
#
#      operatingSystem  operatingSystemVersion  Weight  resolution  touchScren  \
# 0                  5                       0      47           0           0
# 1                  5                       0      81           2           0
# 2                  5                       0      54           2           1
# 3                  5                       1      11           2           0
# 4                  5                       0      56           2           0
# ..               ...                     ...     ...         ...         ...
# 320                5                       0      37           2           1
# 321                5                       0      18           7           1
# 322                5                       0      29           0           0
# 323                5                       0      54           0           0
# 324                5                       0      56           0           0
#
#      screenType  cpuFrequency  cpuModel  secondStorage  secondStorageSize  \
# 0             7            14        31              2                  2
# 1             9            15        33              0                  1
# 2             2            14        31              2                  2
# 3             9            10        17              2                  2
# 4             9            17         0              2                  2
# ..          ...           ...       ...            ...                ...
# 320           2            12        25              2                  2
# 321           3            12        25              2                  2
# 322           7             6         3              2                  2
# 323           7            12        25              2                  2
# 324           7             6         3              2                  2
#
#      primaryStorage  primaryStorageSize
# 0                 1                   1
# 1                 3                   5
# 2                 3                   8
# 3                 3                   2
# 4                 3                   5
# ..              ...                 ...
# 320               3                   2
# 321               3                   8
# 322               0                   9
# 323               1                   1
# 324               1                   7
#
# [325 rows x 18 columns]

# %%
#model 
model = DecisionTreeRegressor()
model.fit(xTest,yTest)
prediction = model.predict(xTest)
r2 = r2_score(yTest, prediction)
print("r2 = " , r2)
# Out:
# r2 =  0.999888509603256

# %%
import csv
csv_file = 'predictions.csv'

with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Prediction'])
    for predict in prediction:
        writer.writerow([predict])

print('Predictions saved successfully to', csv_file)
# Out:
# Predictions saved successfully to predictions.csv
